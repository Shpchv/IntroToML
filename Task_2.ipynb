# %% [markdown]
# <a href="https://colab.research.google.com/github/Shpchv/IntroToML/blob/main/Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Part 1

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
data = pd.read_csv('/content/data.csv', delimiter=';')

# %%
data
# Out:
#    id   X   Y
# 0   1  12  26
# 1   2  17  50
# 2   3   4   9
# 3   4   1   3
# 4   5  10  25
# 5   6   7  19
# 6   7  21  53
# 7   8  18  40
# 8   9  16  26
# 9  10  14  25

# %%
X = data['X']
Y = data['Y']

# %%
print(X.mean())
print(Y.mean())
# Out:
# 12.0
# 27.6

# %%
reg_model = LinearRegression().fit(pd.DataFrame(X), pd.DataFrame(Y))

# %%
# Тета 0
reg_model.intercept_
# Out:
# array([-0.19787234])

# %%
# Тета 1
reg_model.coef_
# Out:
# array([[2.31648936]])

# %%
y_predicted = reg_model.predict(pd.DataFrame(X))
y_predicted
# Out:
# array([[27.6       ],
#        [39.18244681],
#        [ 9.06808511],
#        [ 2.11861702],
#        [22.96702128],
#        [16.01755319],
#        [48.44840426],
#        [41.49893617],
#        [36.86595745],
#        [32.23297872]])

# %%
r2_score(pd.DataFrame(Y), y_predicted)
# Out:
# 0.8606305383221947

# %% [markdown]
# Part 2

# %%
candy_data = pd.read_csv('/candy-data.csv', delimiter=',', index_col='competitorname')
candy_data
# Out:
#                        chocolate  fruity  caramel  peanutyalmondy  nougat  \
# competitorname
# 100 Grand                      1       0        1               0       0
# 3 Musketeers                   1       0        0               0       1
# One dime                       0       0        0               0       0
# One quarter                    0       0        0               0       0
# Air Heads                      0       1        0               0       0
# ...                          ...     ...      ...             ...     ...
# Snickers Crisper               1       0        1               1       0
# Sour Patch Kids                0       1        0               0       0
# Sour Patch Tricksters          0       1        0               0       0
# Starburst                      0       1        0               0       0
# Strawberry bon bons            0       1        0               0       0
#
# ...

# %%
train_data = candy_data.drop(['Dum Dums','Nestle Smarties'])
train_data
# Out:
#                        chocolate  fruity  caramel  peanutyalmondy  nougat  \
# competitorname
# 100 Grand                      1       0        1               0       0
# 3 Musketeers                   1       0        0               0       1
# One dime                       0       0        0               0       0
# One quarter                    0       0        0               0       0
# Air Heads                      0       1        0               0       0
# ...                          ...     ...      ...             ...     ...
# Snickers Crisper               1       0        1               1       0
# Sour Patch Kids                0       1        0               0       0
# Sour Patch Tricksters          0       1        0               0       0
# Starburst                      0       1        0               0       0
# Strawberry bon bons            0       1        0               0       0
#
# ...

# %%
X = pd.DataFrame(train_data.drop(['winpercent', 'Y'], axis=1))

# %%
Y = pd.DataFrame(train_data['winpercent'])

# %%
reg = LinearRegression().fit(X, Y)

# %%
DumDums = candy_data.loc['Dum Dums',:].to_frame().T

reg.predict(DumDums.drop(['winpercent', 'Y'], axis=1))
# Out:
# array([[47.69312171]])

# %%
NestleSmarties = candy_data.loc['Nestle Smarties',:].to_frame().T

reg.predict(NestleSmarties.drop(['winpercent', 'Y'], axis=1))
# Out:
# array([[55.29253178]])

# %%
reg.predict([[1, 1, 1, 1, 0, 1, 0, 0, 0, 0.128, 0.37]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([[87.62803508]])
